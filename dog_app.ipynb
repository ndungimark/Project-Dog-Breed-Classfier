# %% [markdown]
# # Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Dog Identification App
#
# ---
#
# In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested. Sections that begin with **'(IMPLEMENTATION)'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the Jupyter Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to **File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this Jupyter notebook.
#
#
#
# ---
# ### Why We're Here
#
# In this notebook, you will make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, your code will accept any user-supplied image as input.  If a dog is detected in the image, it will provide an estimate of the dog's breed.  If a human is detected, it will provide an estimate of the dog breed that is most resembling.  The image below displays potential sample output of your finished project (... but we expect that each student's algorithm will behave differently!).
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# In this real-world setting, you will need to piece together a series of models to perform different tasks; for instance, the algorithm that detects humans in an image will be different from the CNN that infers dog breed.  There are many points of possible failure, and no perfect algorithm exists.  Your imperfect solution will nonetheless create a fun user experience!
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Import Datasets
# * [Step 1](#step1): Detect Humans
# * [Step 2](#step2): Detect Dogs
# * [Step 3](#step3): Create a CNN to Classify Dog Breeds (from Scratch)
# * [Step 4](#step4): Create a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 5](#step5): Write your Algorithm
# * [Step 6](#step6): Test Your Algorithm
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Datasets
#
# Make sure that you've downloaded the required human and dog datasets:
#
# **Note: if you are using the Udacity workspace, you *DO NOT* need to re-download these - they can be found in the `/data` folder as noted in the cell below.**
#
# * Download the [dog dataset](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/dogImages.zip).  Unzip the folder and place it in this project's home directory, at the location `/dog_images`.
#
# * Download the [human dataset](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/lfw.zip).  Unzip the folder and place it in the home directory, at location `/lfw`.
#
# *Note: If you are using a Windows machine, you are encouraged to use [7zip](http://www.7-zip.org/) to extract the folder.*
#
# In the code cell below, we save the file paths for both the human (LFW) dataset and dog dataset in the numpy arrays `human_files` and `dog_files`.

# %%
import numpy as np
from glob import glob

# load filenames for human and dog images
human_files = np.array(glob("/data/lfw/*/*"))
dog_files = np.array(glob("/data/dog_images/*/*/*"))

# print number of images in each dataset
print('There are %d total human images.' % len(human_files))
print('There are %d total dog images.' % len(dog_files))
# Out:
# There are 13233 total human images.
# There are 8351 total dog images.

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Detect Humans
#
# In this section, we use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.
#
# OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `haarcascades` directory.  In the next code cell, we demonstrate how to use this detector to find human faces in a sample image.

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# load color (BGR) image
img = cv2.imread(human_files[0])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# Before using any of the face detectors, it is standard procedure to convert the images to grayscale.  The `detectMultiScale` function executes the classifier stored in `face_cascade` and takes the grayscale image as a parameter.
#
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.
#
# ### Write a Human Face Detector
#
# We can use this procedure to write a function that returns `True` if a human face is detected in an image and `False` otherwise.  This function, aptly named `face_detector`, takes a string-valued file path to an image as input and appears in the code block below.

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Human Face Detector
#
# __Question 1:__ Use the code cell below to test the performance of the `face_detector` function.
# - What percentage of the first 100 images in `human_files` have a detected human face?
# - What percentage of the first 100 images in `dog_files` have a detected human face?
#
# Ideally, we would like 100% of human images with a detected face and 0% of dog images with a detected face.  You will see that our algorithm falls short of this goal, but still gives acceptable performance.  We extract the file paths for the first 100 images from each of the datasets and store them in the numpy arrays `human_files_short` and `dog_files_short`.

# %% [markdown]
# __Answer:__
# (You can print out your results and/or write your percentages in this cell)
# detect face in human_files: 98 / 100
# detect face in dog_files: 17 / 100

# %%
from tqdm import tqdm

human_files_short = human_files[:100]
dog_files_short = dog_files[:100]

#-#-# Do NOT modify the code above this line. #-#-#

## TODO: Test the performance of the face_detector algorithm 
## on the images in human_files_short and dog_files_short.
def detect_test(files):
    detection_cnt = 0;
    total_cnt = len(files)
    for file in files:
        detection_cnt += face_detector(file)
    return detection_cnt, total_cnt

# %% [markdown]
# We suggest the face detector from OpenCV as a potential way to detect human images in your algorithm, but you are free to explore other approaches, especially approaches that make use of deep learning :).  Please use the code cell below to design and test your own face detection algorithm.  If you decide to pursue this _optional_ task, report performance on `human_files_short` and `dog_files_short`.

# %%
### (Optional) 
### TODO: Test performance of anotherface detection algorithm.
### Feel free to use as many code cells as needed.
print("detect face in human_files: {} / {}".format(detect_test(human_files_short)[0], detect_test(human_files_short)[1]))
print("detect face in dog_files: {} / {}".format(detect_test(dog_files_short)[0], detect_test(dog_files_short)[1]))
# Out:
# detect face in human_files: 98 / 100
# detect face in dog_files: 17 / 100

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Detect Dogs
#
# In this section, we use a [pre-trained model](http://pytorch.org/docs/master/torchvision/models.html) to detect dogs in images.
#
# ### Obtain Pre-trained VGG-16 Model
#
# The code cell below downloads the VGG-16 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
import torch
import torchvision.models as models

# define VGG16 model
VGG16 = models.vgg16(pretrained=True)

# check if CUDA is available
use_cuda = torch.cuda.is_available()

# move model to GPU if CUDA is available
if use_cuda:
    VGG16 = VGG16.cuda()
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.torch/models/vgg16-397923af.pth
# 100%|██████████| 553433881/553433881 [00:05<00:00, 98121002.26it/s]

# %% [markdown]
# Given an image, this pre-trained VGG-16 model returns a prediction (derived from the 1000 possible categories in ImageNet) for the object that is contained in the image.

# %% [markdown]
# ### (IMPLEMENTATION) Making Predictions with a Pre-trained Model
#
# In the next code cell, you will write a function that accepts a path to an image (such as `'dogImages/train/001.Affenpinscher/Affenpinscher_00001.jpg'`) as input and returns the index corresponding to the ImageNet class that is predicted by the pre-trained VGG-16 model.  The output should always be an integer between 0 and 999, inclusive.
#
# Before writing the function, make sure that you take the time to learn  how to appropriately pre-process tensors for pre-trained models in the [PyTorch documentation](http://pytorch.org/docs/stable/torchvision/models.html).

# %%
from PIL import Image
import torchvision.transforms as transforms

def VGG16_predict(img_path):
    '''
    Use pre-trained VGG-16 model to obtain index corresponding to 
    predicted ImageNet class for image at specified path
    
    Args:
        img_path: path to an image
        
    Returns:
        Index corresponding to VGG-16 model's prediction
    '''
    
    ## TODO: Complete the function.
    ## Load and pre-process an image from the given img_path
    ## Return the *index* of the predicted class for that image
    image = Image.open(img_path).convert('RGB')
    in_transform = transforms.Compose([
                        transforms.Resize(size=(244, 244)),
                        transforms.ToTensor()]) 
    image = in_transform(image)[:3,:,:].unsqueeze(0)
    if use_cuda:
        image = image.cuda()
    ret = VGG16(image)
    return torch.max(ret,1)[1].item()

# %% [markdown]
# ### (IMPLEMENTATION) Write a Dog Detector
#
# While looking at the [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a), you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268, inclusive, to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained VGG-16 model, we need only check if the pre-trained model predicts an index between 151 and 268 (inclusive).
#
# Use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    ## TODO: Complete the function.
    idx = VGG16_predict(img_path)
    return idx >= 151 and idx <= 268 # true/false

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Dog Detector
#
# __Question 2:__ Use the code cell below to test the performance of your `dog_detector` function.
# - What percentage of the images in `human_files_short` have a detected dog?
# - What percentage of the images in `dog_files_short` have a detected dog?

# %% [markdown]
# __Answer:__
# detect a dog in human_files: 0 / 100
# detect a dog in dog_files: 98 / 100

# %%
### TODO: Test the performance of the dog_detector function
### on the images in human_files_short and dog_files_short.
def dog_detect_test(files):
    detection_cnt = 0;
    total_cnt = len(files)
    for file in files:
        detection_cnt += dog_detector(file)
    return detection_cnt, total_cnt

# %% [markdown]
# We suggest VGG-16 as a potential network to detect dog images in your algorithm, but you are free to explore other pre-trained networks (such as [Inception-v3](http://pytorch.org/docs/master/torchvision/models.html#inception-v3), [ResNet-50](http://pytorch.org/docs/master/torchvision/models.html#id3), etc).  Please use the code cell below to test other pre-trained PyTorch models.  If you decide to pursue this _optional_ task, report performance on `human_files_short` and `dog_files_short`.

# %%
### (Optional) 
### TODO: Report the performance of another pre-trained network.
### Feel free to use as many code cells as needed.
print("detect a dog in human_files: {} / {}".format(dog_detect_test(human_files_short)[0], dog_detect_test(human_files_short)[1]))
print("detect a dog in dog_files: {} / {}".format(dog_detect_test(dog_files_short)[0], dog_detect_test(dog_files_short)[1]))
# Out:
# detect a dog in human_files: 0 / 100
# detect a dog in dog_files: 98 / 100

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Dog Breeds (from Scratch)
#
# Now that we have functions for detecting humans and dogs in images, we need a way to predict breed from images.  In this step, you will create a CNN that classifies dog breeds.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 10%.  In Step 4 of this notebook, you will have the opportunity to use transfer learning to create a CNN that attains greatly improved accuracy.
#
# We mention that the task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have trouble distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# Brittany | Welsh Springer Spaniel
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# Curly-Coated Retriever | American Water Spaniel
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# Yellow Labrador | Chocolate Labrador | Black Labrador
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# We also mention that random chance presents an exceptionally low bar: setting aside the fact that the classes are slightly imabalanced, a random guess will provide a correct answer roughly 1 in 133 times, which corresponds to an accuracy of less than 1%.
#
# Remember that the practice is far ahead of the theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!
#
# ### (IMPLEMENTATION) Specify Data Loaders for the Dog Dataset
#
# Use the code cell below to write three separate [data loaders](http://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader) for the training, validation, and test datasets of dog images (located at `dog_images/train`, `dog_images/valid`, and `dog_images/test`, respectively).  You may find [this documentation on custom datasets](http://pytorch.org/docs/stable/torchvision/datasets.html) to be a useful resource.  If you are interested in augmenting your training and/or validation data, check out the wide variety of [transforms](http://pytorch.org/docs/stable/torchvision/transforms.html?highlight=transform)!

# %%
import os
from torchvision import datasets

### TODO: Write data loaders for training, validation, and test sets
## Specify appropriate transforms, and batch_sizes
import torchvision.transforms as transforms
import torch
import numpy as np
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

batch_size = 20
num_workers = 0

data_dir = '/data/dog_images/'
train_dir = os.path.join(data_dir, 'train')
valid_dir = os.path.join(data_dir, 'valid')
test_dir = os.path.join(data_dir, 'test')

standard_normalization = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                              std=[0.229, 0.224, 0.225])


data_transforms = {'train': transforms.Compose([transforms.RandomResizedCrop(224),
                                     transforms.RandomHorizontalFlip(),
                                     transforms.ToTensor(),
                                     standard_normalization]),
                   'val': transforms.Compose([transforms.Resize(256),
                                     transforms.CenterCrop(224),
                                     transforms.ToTensor(),
                                     standard_normalization]),
                   'test': transforms.Compose([transforms.Resize(size=(224,224)),
                                     transforms.ToTensor(), 
                                     standard_normalization])
                  }


train_data = datasets.ImageFolder(train_dir, transform=data_transforms['train'])
valid_data = datasets.ImageFolder(valid_dir, transform=data_transforms['val'])
test_data = datasets.ImageFolder(test_dir, transform=data_transforms['test'])



train_loader = torch.utils.data.DataLoader(train_data,
                                           batch_size=batch_size, 
                                           num_workers=num_workers,
                                           shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_data,
                                           batch_size=batch_size, 
                                           num_workers=num_workers,
                                           shuffle=False)
test_loader = torch.utils.data.DataLoader(test_data,
                                           batch_size=batch_size, 
                                           num_workers=num_workers,
                                           shuffle=False)
loaders_scratch = {
    'train': train_loader,
    'valid': valid_loader,
    'test': test_loader
}

# %% [markdown]
# **Question 3:** Describe your chosen procedure for preprocessing the data.
# - How does your code resize the images (by cropping, stretching, etc)?  What size did you pick for the input tensor, and why?
# - Did you decide to augment the dataset?  If so, how (through translations, flips, rotations, etc)?  If not, why not?

# %% [markdown]
# **Answer**:RandomResizedCrop & RandomHorizontalFlip to train_data. That will do image resizing and augmentations.Augmentation gives randomness to the dataset to prevents overfitting and imrove performance on predicting test_data.A Resize of (256) and then, center crop to make 224 X 224.

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  Use the template in the code cell below.

# %%
import torch.nn as nn
import torch.nn.functional as F
dog_classes = 133 #classes of dog breeds
use_cuda = torch.cuda.is_available()
# define the CNN architecture
class Net(nn.Module):
    ### TODO: choose an architecture, and complete the class
    def __init__(self):
        super(Net, self).__init__()
        ## Define layers of a CNN
        self.conv1 = nn.Conv2d(3, 32, 3, stride=2, padding=1)
        self.conv2 = nn.Conv2d(32, 64, 3, stride=2, padding=1)
        self.conv3 = nn.Conv2d(64, 128, 3, padding=1)

        # pool
        self.pool = nn.MaxPool2d(2, 2)
        
        # fully-connected
        self.fc1 = nn.Linear(7*7*128, 500)
        self.fc2 = nn.Linear(500, dog_classes) 
        
        # drop-out
        self.dropout = nn.Dropout(0.3)
    def forward(self, x):
        ## Define forward behavior
        x = F.relu(self.conv1(x))
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        x = self.pool(x)
        x = F.relu(self.conv3(x))
        x = self.pool(x)
        
        # flatten
        x = x.view(-1, 7*7*128)
        
        x = self.dropout(x)
        x = F.relu(self.fc1(x))
        
        x = self.dropout(x)
        x = self.fc2(x)
        return x

#-#-# You so NOT have to modify the code below this line. #-#-#

# instantiate the CNN
model_scratch = Net()
print(model_scratch)
# move tensors to GPU if CUDA is available
if use_cuda:
    model_scratch.cuda()
# Out:
# Net(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=6272, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=133, bias=True)
#   (dropout): Dropout(p=0.3)
# )

# %% [markdown]
# __Question 4:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.

# %% [markdown]
# __Answer:__ First 2 conv layers I've applied kernel_size of 3 with stride 2, this will lead to downsize of input image by 2. after 2 conv layers, maxpooling with stride 2 is placed and this will lead to downsize of input image by 2. The 3rd conv layers is consist of kernel_size of 3 with stride 1, and this will not reduce input image. after final maxpooling with stride 2, the total output image size is downsized by factor of 32 and the depth will be 128. I've applied dropout of 0.3 in order to prevent overfitting. Fully-connected layer is placed and then, 2nd fully-connected layer is intended to produce final output_size which predicts classes of breeds.

# %% [markdown]
# ### (IMPLEMENTATION) Specify Loss Function and Optimizer
#
# Use the next code cell to specify a [loss function](http://pytorch.org/docs/stable/nn.html#loss-functions) and [optimizer](http://pytorch.org/docs/stable/optim.html).  Save the chosen loss function as `criterion_scratch`, and the optimizer as `optimizer_scratch` below.

# %%
import torch.optim as optim

### TODO: select loss function
criterion_scratch = nn.CrossEntropyLoss()

### TODO: select optimizer
optimizer_scratch = optim.SGD(model_scratch.parameters(), lr = 0.05)

# %% [markdown]
# ### (IMPLEMENTATION) Train and Validate the Model
#
# Train and validate your model in the code cell below.  [Save the final model parameters](http://pytorch.org/docs/master/notes/serialization.html) at filepath `'model_scratch.pt'`.

# %%
def train(n_epochs, loaders, model, optimizer, criterion, use_cuda, save_path):
    """returns trained model"""
    # initialize tracker for minimum validation loss
    valid_loss_min = np.Inf 
    
    for epoch in range(1, n_epochs+1):
        # initialize variables to monitor training and validation loss
        train_loss = 0.0
        valid_loss = 0.0
        
        ###################
        # train the model #
        ###################
        model.train()
        for batch_idx, (data, target) in enumerate(loaders['train']):
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
            ## find the loss and update the model parameters accordingly
            ## record the average training loss, using something like
            ## train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            #make weights zero
            optimizer.zero_grad()
            
            output = model(data)
            ##compute loss
            loss = criterion(output, target)
            ##do backward propagation
            loss.backward()
            optimizer.step()
            train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            
            if batch_idx % 100 == 0:
                print('Epoch %d, Batch %d loss: %.6f' %
                  (epoch, batch_idx + 1, train_loss))
        ######################    
        # validate the model #
        ######################
        model.eval()
        for batch_idx, (data, target) in enumerate(loaders['valid']):
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
            ## update the average validation loss
            output=model(data)
            loss=criterion(output,target)
            valid_loss = valid_loss + ((1 / (batch_idx + 1)) * (loss.data - valid_loss))
            
        # print training/validation statistics 
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
            epoch, 
            train_loss,
            valid_loss
            ))
        
        ## TODO: save the model if validation loss has decreased
        if valid_loss < valid_loss_min:
            torch.save(model.state_dict(), save_path)
            print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
            valid_loss_min,
            valid_loss))
            valid_loss_min = valid_loss    
    # return trained model
    return model


# train the model
model_scratch = train(100, loaders_scratch, model_scratch, optimizer_scratch, 
                      criterion_scratch, use_cuda, 'model_scratch.pt')

# load the model that got the best validation accuracy
model_scratch.load_state_dict(torch.load('model_scratch.pt'))
# Out:
# Epoch 1, Batch 1 loss: 4.896930
# Epoch 1, Batch 101 loss: 4.884776
# Epoch 1, Batch 201 loss: 4.880912
# Epoch 1, Batch 301 loss: 4.866066
# Epoch: 1 	Training Loss: 4.862562 	Validation Loss: 4.779562
# Validation loss decreased (inf --> 4.779562).  Saving model ...
# Epoch 2, Batch 1 loss: 4.797680
# Epoch 2, Batch 101 loss: 4.790130
# Epoch 2, Batch 201 loss: 4.745668
# Epoch 2, Batch 301 loss: 4.721207
# Epoch: 2 	Training Loss: 4.713595 	Validation Loss: 4.560577
# Validation loss decreased (4.779562 --> 4.560577).  Saving model ...
# Epoch 3, Batch 1 loss: 4.556872
# Epoch 3, Batch 101 loss: 4.636551
# Epoch 3, Batch 201 loss: 4.632543
# Epoch 3, Batch 301 loss: 4.620136
# Epoch: 3 	Training Loss: 4.613420 	Validation Loss: 4.425128
# Validation loss decreased (4.560577 --> 4.425128).  Saving model ...
# Epoch 4, Batch 1 loss: 4.666809
# Epoch 4, Batch 101 loss: 4.557571
# Epoch 4, Batch 201 loss: 4.553943
# Epoch 4, Batch 301 loss: 4.550826
# Epoch: 4 	Training Loss: 4.549361 	Validation Loss: 4.386851
# Validation loss decreased (4.425128 --> 4.386851).  Saving model ...
# Epoch 5, Batch 1 loss: 4.433658
# Epoch 5, Batch 101 loss: 4.499266
# Epoch 5, Batch 201 loss: 4.493308
# Epoch 5, Batch 301 loss: 4.489790
# Epoch: 5 	Training Loss: 4.484272 	Validation Loss: 4.304077
# Validation loss decreased (4.386851 --> 4.304077).  Saving model ...
# Epoch 6, Batch 1 loss: 4.254313
# Epoch 6, Batch 101 loss: 4.452141
# Epoch 6, Batch 201 loss: 4.444970
# Epoch 6, Batch 301 loss: 4.436029
# Epoch: 6 	Training Loss: 4.434559 	Validation Loss: 4.246829
# Validation loss decreased (4.304077 --> 4.246829).  Saving model ...
# Epoch 7, Batch 1 loss: 4.324769
# Epoch 7, Batch 101 loss: 4.364748
# Epoch 7, Batch 201 loss: 4.379771
# Epoch 7, Batch 301 loss: 4.368214
# Epoch: 7 	Training Loss: 4.364258 	Validation Loss: 4.145094
# Validation loss decreased (4.246829 --> 4.145094).  Saving model ...
# Epoch 8, Batch 1 loss: 4.428916
# Epoch 8, Batch 101 loss: 4.310240
# Epoch 8, Batch 201 loss: 4.303739
# Epoch 8, Batch 301 loss: 4.306926
# Epoch: 8 	Training Loss: 4.305010 	Validation Loss: 4.103071
# Validation loss decreased (4.145094 --> 4.103071).  Saving model ...
# Epoch 9, Batch 1 loss: 4.001455
# Epoch 9, Batch 101 loss: 4.225493
# Epoch 9, Batch 201 loss: 4.234368
# Epoch 9, Batch 301 loss: 4.243831
# Epoch: 9 	Training Loss: 4.245168 	Validation Loss: 4.014620
# Validation loss decreased (4.103071 --> 4.014620).  Saving model ...
# Epoch 10, Batch 1 loss: 3.929076
# Epoch 10, Batch 101 loss: 4.220968
# Epoch 10, Batch 201 loss: 4.211017
# Epoch 10, Batch 301 loss: 4.206857
# Epoch: 10 	Training Loss: 4.203392 	Validation Loss: 4.013729
# Validation loss decreased (4.014620 --> 4.013729).  Saving model ...
# Epoch 11, Batch 1 loss: 4.479925
# Epoch 11, Batch 101 loss: 4.182705
# Epoch 11, Batch 201 loss: 4.165287
# Epoch 11, Batch 301 loss: 4.161289
# Epoch: 11 	Training Loss: 4.154524 	Validation Loss: 3.908143
# Validation loss decreased (4.013729 --> 3.908143).  Saving model ...
# Epoch 12, Batch 1 loss: 3.847962
# Epoch 12, Batch 101 loss: 4.060348
# Epoch 12, Batch 201 loss: 4.075131
# Epoch 12, Batch 301 loss: 4.087596
# Epoch: 12 	Training Loss: 4.093152 	Validation Loss: 3.866786
# Validation loss decreased (3.908143 --> 3.866786).  Saving model ...
# Epoch 13, Batch 1 loss: 3.801345
# Epoch 13, Batch 101 loss: 4.051692
# Epoch 13, Batch 201 loss: 4.032306
# Epoch 13, Batch 301 loss: 4.030246
# Epoch: 13 	Training Loss: 4.033812 	Validation Loss: 3.821811
# Validation loss decreased (3.866786 --> 3.821811).  Saving model ...
# Epoch 14, Batch 1 loss: 3.766523
# Epoch 14, Batch 101 loss: 3.978916
# Epoch 14, Batch 201 loss: 4.004711
# Epoch 14, Batch 301 loss: 3.995959
# Epoch: 14 	Training Loss: 3.998886 	Validation Loss: 3.832295
# Epoch 15, Batch 1 loss: 3.470177
# Epoch 15, Batch 101 loss: 3.941489
# Epoch 15, Batch 201 loss: 3.959264
# Epoch 15, Batch 301 loss: 3.952371
# Epoch: 15 	Training Loss: 3.952052 	Validation Loss: 3.734586
# Validation loss decreased (3.821811 --> 3.734586).  Saving model ...
# Epoch 16, Batch 1 loss: 3.641933
# Epoch 16, Batch 101 loss: 3.877091
# Epoch 16, Batch 201 loss: 3.907970
# Epoch 16, Batch 301 loss: 3.911776
# Epoch: 16 	Training Loss: 3.914359 	Validation Loss: 3.819871
# Epoch 17, Batch 1 loss: 3.955711
# Epoch 17, Batch 101 loss: 3.873441
# Epoch 17, Batch 201 loss: 3.867809
# Epoch 17, Batch 301 loss: 3.873337
# Epoch: 17 	Training Loss: 3.875674 	Validation Loss: 3.787264
# Epoch 18, Batch 1 loss: 3.809420
# Epoch 18, Batch 101 loss: 3.832710
# Epoch 18, Batch 201 loss: 3.826599
# Epoch 18, Batch 301 loss: 3.832214
# Epoch: 18 	Training Loss: 3.830009 	Validation Loss: 3.692053
# Validation loss decreased (3.734586 --> 3.692053).  Saving model ...
# Epoch 19, Batch 1 loss: 3.737672
# Epoch 19, Batch 101 loss: 3.788305
# Epoch 19, Batch 201 loss: 3.775970
# Epoch 19, Batch 301 loss: 3.789355
# Epoch: 19 	Training Loss: 3.790387 	Validation Loss: 3.636169
# Validation loss decreased (3.692053 --> 3.636169).  Saving model ...
# Epoch 20, Batch 1 loss: 3.450785
# Epoch 20, Batch 101 loss: 3.699924
# Epoch 20, Batch 201 loss: 3.713151
# Epoch 20, Batch 301 loss: 3.718694
# Epoch: 20 	Training Loss: 3.718145 	Validation Loss: 3.573614
# Validation loss decreased (3.636169 --> 3.573614).  Saving model ...
# Epoch 21, Batch 1 loss: 3.500179
# Epoch 21, Batch 101 loss: 3.679244
# Epoch 21, Batch 201 loss: 3.693426
# Epoch 21, Batch 301 loss: 3.700504
# Epoch: 21 	Training Loss: 3.700052 	Validation Loss: 3.520365
# Validation loss decreased (3.573614 --> 3.520365).  Saving model ...
# Epoch 22, Batch 1 loss: 3.347555
# Epoch 22, Batch 101 loss: 3.692621
# Epoch 22, Batch 201 loss: 3.652913
# Epoch 22, Batch 301 loss: 3.658523
# Epoch: 22 	Training Loss: 3.663950 	Validation Loss: 3.481346
# Validation loss decreased (3.520365 --> 3.481346).  Saving model ...
# Epoch 23, Batch 1 loss: 3.971601
# Epoch 23, Batch 101 loss: 3.626350
# Epoch 23, Batch 201 loss: 3.605352
# Epoch 23, Batch 301 loss: 3.614940
# Epoch: 23 	Training Loss: 3.617326 	Validation Loss: 3.494298
# Epoch 24, Batch 1 loss: 3.524619
# Epoch 24, Batch 101 loss: 3.585601
# Epoch 24, Batch 201 loss: 3.568615
# Epoch 24, Batch 301 loss: 3.583379
# Epoch: 24 	Training Loss: 3.578527 	Validation Loss: 3.535999
# Epoch 25, Batch 1 loss: 4.281182
# Epoch 25, Batch 101 loss: 3.553160
# Epoch 25, Batch 201 loss: 3.557813
# Epoch 25, Batch 301 loss: 3.562290
# Epoch: 25 	Training Loss: 3.560175 	Validation Loss: 3.457708
# Validation loss decreased (3.481346 --> 3.457708).  Saving model ...
# Epoch 26, Batch 1 loss: 3.760311
# Epoch 26, Batch 101 loss: 3.492238
# Epoch 26, Batch 201 loss: 3.479679
# Epoch 26, Batch 301 loss: 3.488209
# Epoch: 26 	Training Loss: 3.495552 	Validation Loss: 3.433160
# Validation loss decreased (3.457708 --> 3.433160).  Saving model ...
# Epoch 27, Batch 1 loss: 3.206847
# Epoch 27, Batch 101 loss: 3.465156
# Epoch 27, Batch 201 loss: 3.476038
# Epoch 27, Batch 301 loss: 3.491863
# Epoch: 27 	Training Loss: 3.496217 	Validation Loss: 3.339776
# Validation loss decreased (3.433160 --> 3.339776).  Saving model ...
# Epoch 28, Batch 1 loss: 3.222015
# Epoch 28, Batch 101 loss: 3.409595
# Epoch 28, Batch 201 loss: 3.432356
# Epoch 28, Batch 301 loss: 3.437723
# Epoch: 28 	Training Loss: 3.442860 	Validation Loss: 3.350291
# Epoch 29, Batch 1 loss: 3.777991
# Epoch 29, Batch 101 loss: 3.381443
# Epoch 29, Batch 201 loss: 3.396478
# Epoch 29, Batch 301 loss: 3.417672
# Epoch: 29 	Training Loss: 3.406717 	Validation Loss: 3.299721
# Validation loss decreased (3.339776 --> 3.299721).  Saving model ...
# Epoch 30, Batch 1 loss: 3.162165
# Epoch 30, Batch 101 loss: 3.298505
# Epoch 30, Batch 201 loss: 3.371280
# Epoch 30, Batch 301 loss: 3.364627
# Epoch: 30 	Training Loss: 3.366029 	Validation Loss: 3.269450
# Validation loss decreased (3.299721 --> 3.269450).  Saving model ...
# Epoch 31, Batch 1 loss: 3.297148
# Epoch 31, Batch 101 loss: 3.358457
# Epoch 31, Batch 201 loss: 3.384412
# Epoch 31, Batch 301 loss: 3.367877
# Epoch: 31 	Training Loss: 3.367539 	Validation Loss: 3.315289
# Epoch 32, Batch 1 loss: 3.267900
# Epoch 32, Batch 101 loss: 3.305607
# Epoch 32, Batch 201 loss: 3.311149
# Epoch 32, Batch 301 loss: 3.322447
# Epoch: 32 	Training Loss: 3.325923 	Validation Loss: 3.235209
# Validation loss decreased (3.269450 --> 3.235209).  Saving model ...
# Epoch 33, Batch 1 loss: 3.105389
# Epoch 33, Batch 101 loss: 3.243978
# Epoch 33, Batch 201 loss: 3.286304
# Epoch 33, Batch 301 loss: 3.277883
# Epoch: 33 	Training Loss: 3.281046 	Validation Loss: 3.231063
# Validation loss decreased (3.235209 --> 3.231063).  Saving model ...
# Epoch 34, Batch 1 loss: 3.358505
# Epoch 34, Batch 101 loss: 3.259930
# Epoch 34, Batch 201 loss: 3.276493
# Epoch 34, Batch 301 loss: 3.285579
# Epoch: 34 	Training Loss: 3.278170 	Validation Loss: 3.588333
# Epoch 35, Batch 1 loss: 3.469740
# Epoch 35, Batch 101 loss: 3.183565
# Epoch 35, Batch 201 loss: 3.207772
# Epoch 35, Batch 301 loss: 3.229317
# Epoch: 35 	Training Loss: 3.235546 	Validation Loss: 3.180100
# Validation loss decreased (3.231063 --> 3.180100).  Saving model ...
# Epoch 36, Batch 1 loss: 3.261985
# Epoch 36, Batch 101 loss: 3.247380
# Epoch 36, Batch 201 loss: 3.213104
# Epoch 36, Batch 301 loss: 3.239349
# Epoch: 36 	Training Loss: 3.231776 	Validation Loss: 3.161078
# Validation loss decreased (3.180100 --> 3.161078).  Saving model ...
# Epoch 37, Batch 1 loss: 3.035256
# Epoch 37, Batch 101 loss: 3.147656
# Epoch 37, Batch 201 loss: 3.177040
# Epoch 37, Batch 301 loss: 3.184164
# Epoch: 37 	Training Loss: 3.179515 	Validation Loss: 3.313887
# Epoch 38, Batch 1 loss: 2.375289
# Epoch 38, Batch 101 loss: 3.158369
# Epoch 38, Batch 201 loss: 3.139901
# Epoch 38, Batch 301 loss: 3.145441
# Epoch: 38 	Training Loss: 3.151689 	Validation Loss: 3.233989
# Epoch 39, Batch 1 loss: 2.556981
# Epoch 39, Batch 101 loss: 3.090089
# Epoch 39, Batch 201 loss: 3.118767
# Epoch 39, Batch 301 loss: 3.128771
# Epoch: 39 	Training Loss: 3.134003 	Validation Loss: 3.183138
# Epoch 40, Batch 1 loss: 2.922368
# Epoch 40, Batch 101 loss: 3.047733
# Epoch 40, Batch 201 loss: 3.096027
# Epoch 40, Batch 301 loss: 3.130499
# Epoch: 40 	Training Loss: 3.130318 	Validation Loss: 3.228642
# Epoch 41, Batch 1 loss: 2.992470
# Epoch 41, Batch 101 loss: 3.130900
# Epoch 41, Batch 201 loss: 3.158348
# Epoch 41, Batch 301 loss: 3.159027
# Epoch: 41 	Training Loss: 3.157853 	Validation Loss: 3.197471
# Epoch 42, Batch 1 loss: 3.442799
# Epoch 42, Batch 101 loss: 3.068362
# Epoch 42, Batch 201 loss: 3.060095
# Epoch 42, Batch 301 loss: 3.065099
# Epoch: 42 	Training Loss: 3.070978 	Validation Loss: 3.270573
# Epoch 43, Batch 1 loss: 3.284537
# Epoch 43, Batch 101 loss: 2.993660
# Epoch 43, Batch 201 loss: 3.032669
# Epoch 43, Batch 301 loss: 3.016546
# Epoch: 43 	Training Loss: 3.032988 	Validation Loss: 3.170382
# Epoch 44, Batch 1 loss: 2.680887
# Epoch 44, Batch 101 loss: 2.995579
# Epoch 44, Batch 201 loss: 3.039223
# Epoch 44, Batch 301 loss: 3.043702
# Epoch: 44 	Training Loss: 3.054833 	Validation Loss: 3.114191
# Validation loss decreased (3.161078 --> 3.114191).  Saving model ...
# Epoch 45, Batch 1 loss: 3.516303
# Epoch 45, Batch 101 loss: 2.948882
# Epoch 45, Batch 201 loss: 2.983885
# Epoch 45, Batch 301 loss: 3.009264
# Epoch: 45 	Training Loss: 3.016453 	Validation Loss: 3.187969
# Epoch 46, Batch 1 loss: 3.260404
# Epoch 46, Batch 101 loss: 2.978812
# Epoch 46, Batch 201 loss: 2.970815
# Epoch 46, Batch 301 loss: 2.979627
# Epoch: 46 	Training Loss: 2.977553 	Validation Loss: 3.176899
# Epoch 47, Batch 1 loss: 2.829567
# Epoch 47, Batch 101 loss: 2.962148
# Epoch 47, Batch 201 loss: 2.991176
# Epoch 47, Batch 301 loss: 2.995170
# Epoch: 47 	Training Loss: 2.998347 	Validation Loss: 3.207232
# Epoch 48, Batch 1 loss: 3.047229
# Epoch 48, Batch 101 loss: 2.869946
# Epoch 48, Batch 201 loss: 2.940756
# Epoch 48, Batch 301 loss: 2.959168
# Epoch: 48 	Training Loss: 2.958066 	Validation Loss: 3.106516
# Validation loss decreased (3.114191 --> 3.106516).  Saving model ...
# Epoch 49, Batch 1 loss: 2.775439
# Epoch 49, Batch 101 loss: 2.944297
# Epoch 49, Batch 201 loss: 2.964101
# Epoch 49, Batch 301 loss: 2.945331
# Epoch: 49 	Training Loss: 2.947450 	Validation Loss: 3.277482
# Epoch 50, Batch 1 loss: 3.130948
# Epoch 50, Batch 101 loss: 2.967763
# Epoch 50, Batch 201 loss: 2.987635
# Epoch 50, Batch 301 loss: 2.962729
# Epoch: 50 	Training Loss: 2.965748 	Validation Loss: 3.152831
# Epoch 51, Batch 1 loss: 2.337525
# Epoch 51, Batch 101 loss: 2.802469
# Epoch 51, Batch 201 loss: 2.841604
# Epoch 51, Batch 301 loss: 2.880627
# Epoch: 51 	Training Loss: 2.887111 	Validation Loss: 3.334172
# Epoch 52, Batch 1 loss: 2.902897
# Epoch 52, Batch 101 loss: 2.780432
# Epoch 52, Batch 201 loss: 2.848477
# Epoch 52, Batch 301 loss: 2.892678
# Epoch: 52 	Training Loss: 2.893255 	Validation Loss: 3.216197
# Epoch 53, Batch 1 loss: 2.086581
# Epoch 53, Batch 101 loss: 2.891011
# Epoch 53, Batch 201 loss: 2.903667
# Epoch 53, Batch 301 loss: 2.885250
# Epoch: 53 	Training Loss: 2.895315 	Validation Loss: 3.164077
# Epoch 54, Batch 1 loss: 3.519846
# Epoch 54, Batch 101 loss: 2.839241
# Epoch 54, Batch 201 loss: 2.839628
# Epoch 54, Batch 301 loss: 2.864949
# Epoch: 54 	Training Loss: 2.874980 	Validation Loss: 3.113629
# Epoch 55, Batch 1 loss: 2.237867
# Epoch 55, Batch 101 loss: 2.846840
# Epoch 55, Batch 201 loss: 2.849360
# Epoch 55, Batch 301 loss: 2.874370
# Epoch: 55 	Training Loss: 2.870595 	Validation Loss: 3.190891
# Epoch 56, Batch 1 loss: 3.596524
# Epoch 56, Batch 101 loss: 2.877417
# Epoch 56, Batch 201 loss: 2.855187
# Epoch 56, Batch 301 loss: 2.843233
# Epoch: 56 	Training Loss: 2.854301 	Validation Loss: 3.091845
# Validation loss decreased (3.106516 --> 3.091845).  Saving model ...
# Epoch 57, Batch 1 loss: 3.197415
# Epoch 57, Batch 101 loss: 2.814587
# Epoch 57, Batch 201 loss: 2.835214
# Epoch 57, Batch 301 loss: 2.855314
# Epoch: 57 	Training Loss: 2.861115 	Validation Loss: 3.116990
# Epoch 58, Batch 1 loss: 2.752938
# Epoch 58, Batch 101 loss: 2.756999
# Epoch 58, Batch 201 loss: 2.757697
# Epoch 58, Batch 301 loss: 2.798567
# Epoch: 58 	Training Loss: 2.797374 	Validation Loss: 3.139245
# Epoch 59, Batch 1 loss: 3.039485
# Epoch 59, Batch 101 loss: 2.750159
# Epoch 59, Batch 201 loss: 2.769029
# Epoch 59, Batch 301 loss: 2.808801
# Epoch: 59 	Training Loss: 2.802796 	Validation Loss: 3.168799
# Epoch 60, Batch 1 loss: 3.551136
# Epoch 60, Batch 101 loss: 2.790973
# Epoch 60, Batch 201 loss: 2.810252
# Epoch 60, Batch 301 loss: 2.839588
# Epoch: 60 	Training Loss: 2.845296 	Validation Loss: 3.269728
# Epoch 61, Batch 1 loss: 2.350421
# Epoch 61, Batch 101 loss: 2.677760
# Epoch 61, Batch 201 loss: 2.702299
# Epoch 61, Batch 301 loss: 2.735533
# Epoch: 61 	Training Loss: 2.740877 	Validation Loss: 3.189001
# Epoch 62, Batch 1 loss: 2.662293
# Epoch 62, Batch 101 loss: 2.763674
# Epoch 62, Batch 201 loss: 2.752935
# Epoch 62, Batch 301 loss: 2.783561
# Epoch: 62 	Training Loss: 2.782808 	Validation Loss: 3.198986
# Epoch 63, Batch 1 loss: 2.361352
# Epoch 63, Batch 101 loss: 2.670667
# Epoch 63, Batch 201 loss: 2.704567
# Epoch 63, Batch 301 loss: 2.725256
# Epoch: 63 	Training Loss: 2.739493 	Validation Loss: 3.146205
# Epoch 64, Batch 1 loss: 2.825826
# Epoch 64, Batch 101 loss: 2.736803
# Epoch 64, Batch 201 loss: 2.752415
# Epoch 64, Batch 301 loss: 2.741047
# Epoch: 64 	Training Loss: 2.744033 	Validation Loss: 3.088433
# Validation loss decreased (3.091845 --> 3.088433).  Saving model ...
# Epoch 65, Batch 1 loss: 2.847853
# Epoch 65, Batch 101 loss: 2.700898
# Epoch 65, Batch 201 loss: 2.690077
# Epoch 65, Batch 301 loss: 2.702069
# Epoch: 65 	Training Loss: 2.726930 	Validation Loss: 3.148027
# Epoch 66, Batch 1 loss: 2.871870
# Epoch 66, Batch 101 loss: 2.698002
# Epoch 66, Batch 201 loss: 2.729287
# Epoch 66, Batch 301 loss: 2.745181
# Epoch: 66 	Training Loss: 2.747600 	Validation Loss: 3.137230
# Epoch 67, Batch 1 loss: 2.175515
# Epoch 67, Batch 101 loss: 2.638479
# Epoch 67, Batch 201 loss: 2.656578
# Epoch 67, Batch 301 loss: 2.684773
# Epoch: 67 	Training Loss: 2.690439 	Validation Loss: 3.104774
# Epoch 68, Batch 1 loss: 2.694433
# Epoch 68, Batch 101 loss: 2.723406
# Epoch 68, Batch 201 loss: 2.730508
# Epoch 68, Batch 301 loss: 2.731725
# Epoch: 68 	Training Loss: 2.733722 	Validation Loss: 3.208327
# Epoch 69, Batch 1 loss: 2.437149
# Epoch 69, Batch 101 loss: 2.611545
# Epoch 69, Batch 201 loss: 2.671981
# Epoch 69, Batch 301 loss: 2.702790
# Epoch: 69 	Training Loss: 2.722661 	Validation Loss: 3.058176
# Validation loss decreased (3.088433 --> 3.058176).  Saving model ...
# Epoch 70, Batch 1 loss: 2.343061
# Epoch 70, Batch 101 loss: 2.640240
# Epoch 70, Batch 201 loss: 2.677523
# Epoch 70, Batch 301 loss: 2.694404
# Epoch: 70 	Training Loss: 2.701402 	Validation Loss: 3.174627
# Epoch 71, Batch 1 loss: 2.962132
# Epoch 71, Batch 101 loss: 2.660583
# Epoch 71, Batch 201 loss: 2.664703
# Epoch 71, Batch 301 loss: 2.673752
# Epoch: 71 	Training Loss: 2.661863 	Validation Loss: 3.122190
# Epoch 72, Batch 1 loss: 2.029184
# Epoch 72, Batch 101 loss: 2.621777
# Epoch 72, Batch 201 loss: 2.659287
# Epoch 72, Batch 301 loss: 2.670074
# Epoch: 72 	Training Loss: 2.671185 	Validation Loss: 3.012839
# Validation loss decreased (3.058176 --> 3.012839).  Saving model ...
# Epoch 73, Batch 1 loss: 2.371457
# Epoch 73, Batch 101 loss: 2.582037
# Epoch 73, Batch 201 loss: 2.672326
# Epoch 73, Batch 301 loss: 2.666804
# Epoch: 73 	Training Loss: 2.673010 	Validation Loss: 3.085923
# Epoch 74, Batch 1 loss: 3.251950
# Epoch 74, Batch 101 loss: 2.624893
# Epoch 74, Batch 201 loss: 2.640596
# Epoch 74, Batch 301 loss: 2.648407
# Epoch: 74 	Training Loss: 2.643779 	Validation Loss: 3.094361
# Epoch 75, Batch 1 loss: 2.956751
# Epoch 75, Batch 101 loss: 2.615312
# Epoch 75, Batch 201 loss: 2.650961
# Epoch 75, Batch 301 loss: 2.655314
# Epoch: 75 	Training Loss: 2.666381 	Validation Loss: 3.120474
# Epoch 76, Batch 1 loss: 2.593444
# Epoch 76, Batch 101 loss: 2.608648
# Epoch 76, Batch 201 loss: 2.650063
# Epoch 76, Batch 301 loss: 2.667526
# Epoch: 76 	Training Loss: 2.664008 	Validation Loss: 3.116908
# Epoch 77, Batch 1 loss: 2.295404
# Epoch 77, Batch 101 loss: 2.522336
# Epoch 77, Batch 201 loss: 2.607270
# Epoch 77, Batch 301 loss: 2.609521
# Epoch: 77 	Training Loss: 2.610938 	Validation Loss: 3.133904
# Epoch 78, Batch 1 loss: 1.785506
# Epoch 78, Batch 101 loss: 2.569960
# Epoch 78, Batch 201 loss: 2.595570
# Epoch 78, Batch 301 loss: 2.620582
# Epoch: 78 	Training Loss: 2.628304 	Validation Loss: 3.055936
# Epoch 79, Batch 1 loss: 1.847059
# Epoch 79, Batch 101 loss: 2.578321
# Epoch 79, Batch 201 loss: 2.573541
# Epoch 79, Batch 301 loss: 2.588178
# Epoch: 79 	Training Loss: 2.598155 	Validation Loss: 3.257806
# Epoch 80, Batch 1 loss: 2.381095
# Epoch 80, Batch 101 loss: 2.611878
# Epoch 80, Batch 201 loss: 2.637955
# Epoch 80, Batch 301 loss: 2.620453
# Epoch: 80 	Training Loss: 2.618966 	Validation Loss: 3.130698
# Epoch 81, Batch 1 loss: 2.271565
# Epoch 81, Batch 101 loss: 2.461520
# Epoch 81, Batch 201 loss: 2.512312
# Epoch 81, Batch 301 loss: 2.558852
# Epoch: 81 	Training Loss: 2.562650 	Validation Loss: 3.266459
# Epoch 82, Batch 1 loss: 3.321789
# Epoch 82, Batch 101 loss: 2.572622
# Epoch 82, Batch 201 loss: 2.607656
# Epoch 82, Batch 301 loss: 2.611301
# Epoch: 82 	Training Loss: 2.622637 	Validation Loss: 3.148649
# Epoch 83, Batch 1 loss: 2.308057
# Epoch 83, Batch 101 loss: 2.534856
# Epoch 83, Batch 201 loss: 2.576709
# Epoch 83, Batch 301 loss: 2.586573
# Epoch: 83 	Training Loss: 2.585463 	Validation Loss: 3.217090
# Epoch 84, Batch 1 loss: 2.371876
# Epoch 84, Batch 101 loss: 2.507988
# Epoch 84, Batch 201 loss: 2.543457
# Epoch 84, Batch 301 loss: 2.558125
# Epoch: 84 	Training Loss: 2.564040 	Validation Loss: 3.149202
# Epoch 85, Batch 1 loss: 2.906860
# Epoch 85, Batch 101 loss: 2.591283
# Epoch 85, Batch 201 loss: 2.630789
# Epoch 85, Batch 301 loss: 2.617772
# Epoch: 85 	Training Loss: 2.609414 	Validation Loss: 3.219411
# Epoch 86, Batch 1 loss: 2.309436
# Epoch 86, Batch 101 loss: 2.580482
# Epoch 86, Batch 201 loss: 2.590334
# Epoch 86, Batch 301 loss: 2.588836
# Epoch: 86 	Training Loss: 2.590626 	Validation Loss: 3.059976
# Epoch 87, Batch 1 loss: 3.408931
# Epoch 87, Batch 101 loss: 2.641334
# Epoch 87, Batch 201 loss: 2.566756
# Epoch 87, Batch 301 loss: 2.564383
# Epoch: 87 	Training Loss: 2.579921 	Validation Loss: 3.085934
# Epoch 88, Batch 1 loss: 1.754092
# Epoch 88, Batch 101 loss: 2.460597
# Epoch 88, Batch 201 loss: 2.511564
# Epoch 88, Batch 301 loss: 2.535131
# Epoch: 88 	Training Loss: 2.545105 	Validation Loss: 3.176963
# Epoch 89, Batch 1 loss: 2.369845
# Epoch 89, Batch 101 loss: 2.579879
# Epoch 89, Batch 201 loss: 2.612490
# Epoch 89, Batch 301 loss: 2.600394
# Epoch: 89 	Training Loss: 2.597498 	Validation Loss: 3.154199
# Epoch 90, Batch 1 loss: 1.751268
# Epoch 90, Batch 101 loss: 2.553241
# Epoch 90, Batch 201 loss: 2.543709
# Epoch 90, Batch 301 loss: 2.565605
# Epoch: 90 	Training Loss: 2.571777 	Validation Loss: 3.090295
# Epoch 91, Batch 1 loss: 2.783177
# Epoch 91, Batch 101 loss: 2.522051
# Epoch 91, Batch 201 loss: 2.523216
# Epoch 91, Batch 301 loss: 2.533177
# Epoch: 91 	Training Loss: 2.548125 	Validation Loss: 3.125413
# Epoch 92, Batch 1 loss: 2.522873
# Epoch 92, Batch 101 loss: 2.526489
# Epoch 92, Batch 201 loss: 2.523979
# Epoch 92, Batch 301 loss: 2.514577
# Epoch: 92 	Training Loss: 2.518056 	Validation Loss: 3.170712
# Epoch 93, Batch 1 loss: 2.207758
# Epoch 93, Batch 101 loss: 2.499140
# Epoch 93, Batch 201 loss: 2.481112
# Epoch 93, Batch 301 loss: 2.488113
# Epoch: 93 	Training Loss: 2.498575 	Validation Loss: 3.162394
# Epoch 94, Batch 1 loss: 2.297466
# Epoch 94, Batch 101 loss: 2.477021
# Epoch 94, Batch 201 loss: 2.534781
# Epoch 94, Batch 301 loss: 2.536919
# Epoch: 94 	Training Loss: 2.533598 	Validation Loss: 3.331336
# Epoch 95, Batch 1 loss: 3.027690
# Epoch 95, Batch 101 loss: 2.431852
# Epoch 95, Batch 201 loss: 2.496344
# Epoch 95, Batch 301 loss: 2.527359
# Epoch: 95 	Training Loss: 2.540235 	Validation Loss: 3.174018
# Epoch 96, Batch 1 loss: 2.430368
# Epoch 96, Batch 101 loss: 2.440577
# Epoch 96, Batch 201 loss: 2.484625
# Epoch 96, Batch 301 loss: 2.506113
# Epoch: 96 	Training Loss: 2.506369 	Validation Loss: 3.054234
# Epoch 97, Batch 1 loss: 1.961566
# Epoch 97, Batch 101 loss: 2.422554
# Epoch 97, Batch 201 loss: 2.467408
# Epoch 97, Batch 301 loss: 2.499992
# Epoch: 97 	Training Loss: 2.506666 	Validation Loss: 3.133652
# Epoch 98, Batch 1 loss: 2.354964
# Epoch 98, Batch 101 loss: 2.461773
# Epoch 98, Batch 201 loss: 2.465561
# Epoch 98, Batch 301 loss: 2.481325
# Epoch: 98 	Training Loss: 2.488414 	Validation Loss: 3.261970
# Epoch 99, Batch 1 loss: 2.363066
# Epoch 99, Batch 101 loss: 2.438821
# Epoch 99, Batch 201 loss: 2.447120
# Epoch 99, Batch 301 loss: 2.498824
# Epoch: 99 	Training Loss: 2.485410 	Validation Loss: 3.328273
# Epoch 100, Batch 1 loss: 1.463132
# Epoch 100, Batch 101 loss: 2.441597
# Epoch 100, Batch 201 loss: 2.451905
# Epoch 100, Batch 301 loss: 2.474895
# Epoch: 100 	Training Loss: 2.485429 	Validation Loss: 3.226084

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images.  Use the code cell below to calculate and print the test loss and accuracy.  Ensure that your test accuracy is greater than 10%.

# %%
def test(loaders, model, criterion, use_cuda):

    # monitor test loss and accuracy
    test_loss = 0.
    correct = 0.
    total = 0.

    model.eval()
    for batch_idx, (data, target) in enumerate(loaders['test']):
        # move to GPU
        if use_cuda:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # update average test loss 
        test_loss = test_loss + ((1 / (batch_idx + 1)) * (loss.data - test_loss))
        # convert output probabilities to predicted class
        pred = output.data.max(1, keepdim=True)[1]
        # compare predictions to true label
        correct += np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
        total += data.size(0)
            
    print('Test Loss: {:.6f}\n'.format(test_loss))

    print('\nTest Accuracy: %2d%% (%2d/%2d)' % (
        100. * correct / total, correct, total))

# call test function    
test(loaders_scratch, model_scratch, criterion_scratch, use_cuda)
# Out:
# Test Loss: 3.225189
#
#
# Test Accuracy: 24% (201/836)

# %% [markdown]
# ---
# <a id='step4'></a>
# ## Step 4: Create a CNN to Classify Dog Breeds (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify dog breed from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# ### (IMPLEMENTATION) Specify Data Loaders for the Dog Dataset
#
# Use the code cell below to write three separate [data loaders](http://pytorch.org/docs/master/data.html#torch.utils.data.DataLoader) for the training, validation, and test datasets of dog images (located at `dogImages/train`, `dogImages/valid`, and `dogImages/test`, respectively).
#
# If you like, **you are welcome to use the same data loaders from the previous step**, when you created a CNN from scratch.

# %%
## TODO: Specify data loaders
loaders_transfer = loaders_scratch.copy()

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Use transfer learning to create a CNN to classify dog breed.  Use the code cell below, and save your initialized model as the variable `model_transfer`.

# %%
import torchvision.models as models
import torch.nn as nn

## TODO: Specify model architecture 
model_transfer = models.resnet50(pretrained=True)
for param in model_transfer.parameters():
    param.requires_grad = False
model_transfer.fc = nn.Linear(2048, 133, bias=True)
fc_parameters = model_transfer.fc.parameters()
for param in fc_parameters:
    param.requires_grad = True
model_transfer
if use_cuda:
    model_transfer = model_transfer.cuda()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.torch/models/resnet50-19c8e357.pth
# 100%|██████████| 102502400/102502400 [00:01<00:00, 99526088.03it/s]

# %% [markdown]
# __Question 5:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.

# %% [markdown]
# __Answer:__ I have chosen ResNet as a transfer model because it performed outstanding on Image Classification.Have removed final Fully-connected layer and replaced with Fully-connected layer with output of 133

# %% [markdown]
# ### (IMPLEMENTATION) Specify Loss Function and Optimizer
#
# Use the next code cell to specify a [loss function](http://pytorch.org/docs/master/nn.html#loss-functions) and [optimizer](http://pytorch.org/docs/master/optim.html).  Save the chosen loss function as `criterion_transfer`, and the optimizer as `optimizer_transfer` below.

# %%
criterion_transfer = nn.CrossEntropyLoss()
optimizer_transfer = optim.SGD(model_transfer.fc.parameters(), lr=0.001)

# %% [markdown]
# ### (IMPLEMENTATION) Train and Validate the Model
#
# Train and validate your model in the code cell below.  [Save the final model parameters](http://pytorch.org/docs/master/notes/serialization.html) at filepath `'model_transfer.pt'`.

# %%
# train the model
n_epochs=20
model_transfer = train(n_epochs, loaders_transfer, model_transfer, optimizer_transfer, criterion_transfer, use_cuda, 'model_transfer.pt')

# load the model that got the best validation accuracy (uncomment the line below)
model_transfer.load_state_dict(torch.load('model_transfer.pt'))
# Out:
# Epoch 1, Batch 1 loss: 4.918973
# Epoch 1, Batch 101 loss: 4.920196
# Epoch 1, Batch 201 loss: 4.881742
# Epoch 1, Batch 301 loss: 4.842031
# Epoch: 1 	Training Loss: 4.831039 	Validation Loss: 4.655468
# Validation loss decreased (inf --> 4.655468).  Saving model ...
# Epoch 2, Batch 1 loss: 4.713718
# Epoch 2, Batch 101 loss: 4.662734
# Epoch 2, Batch 201 loss: 4.643255
# Epoch 2, Batch 301 loss: 4.613597
# Epoch: 2 	Training Loss: 4.606321 	Validation Loss: 4.405869
# Validation loss decreased (4.655468 --> 4.405869).  Saving model ...
# Epoch 3, Batch 1 loss: 4.484235
# Epoch 3, Batch 101 loss: 4.474656
# Epoch 3, Batch 201 loss: 4.448411
# Epoch 3, Batch 301 loss: 4.422411
# Epoch: 3 	Training Loss: 4.415235 	Validation Loss: 4.167258
# Validation loss decreased (4.405869 --> 4.167258).  Saving model ...
# Epoch 4, Batch 1 loss: 4.223796
# Epoch 4, Batch 101 loss: 4.281550
# Epoch 4, Batch 201 loss: 4.254358
# Epoch 4, Batch 301 loss: 4.234358
# Epoch: 4 	Training Loss: 4.225670 	Validation Loss: 3.953231
# Validation loss decreased (4.167258 --> 3.953231).  Saving model ...
# Epoch 5, Batch 1 loss: 4.091436
# Epoch 5, Batch 101 loss: 4.083467
# Epoch 5, Batch 201 loss: 4.073349
# Epoch 5, Batch 301 loss: 4.049986
# Epoch: 5 	Training Loss: 4.043176 	Validation Loss: 3.706988
# Validation loss decreased (3.953231 --> 3.706988).  Saving model ...
# Epoch 6, Batch 1 loss: 3.981097
# Epoch 6, Batch 101 loss: 3.936774
# Epoch 6, Batch 201 loss: 3.915843
# Epoch 6, Batch 301 loss: 3.891918
# Epoch: 6 	Training Loss: 3.884550 	Validation Loss: 3.517545
# Validation loss decreased (3.706988 --> 3.517545).  Saving model ...
# Epoch 7, Batch 1 loss: 3.883870
# Epoch 7, Batch 101 loss: 3.762712
# Epoch 7, Batch 201 loss: 3.747952
# Epoch 7, Batch 301 loss: 3.734188
# Epoch: 7 	Training Loss: 3.726653 	Validation Loss: 3.348516
# Validation loss decreased (3.517545 --> 3.348516).  Saving model ...
# Epoch 8, Batch 1 loss: 3.818262
# Epoch 8, Batch 101 loss: 3.623091
# Epoch 8, Batch 201 loss: 3.590023
# Epoch 8, Batch 301 loss: 3.569964
# Epoch: 8 	Training Loss: 3.571516 	Validation Loss: 3.159324
# Validation loss decreased (3.348516 --> 3.159324).  Saving model ...
# Epoch 9, Batch 1 loss: 3.517366
# Epoch 9, Batch 101 loss: 3.463596
# Epoch 9, Batch 201 loss: 3.446463
# Epoch 9, Batch 301 loss: 3.434296
# Epoch: 9 	Training Loss: 3.428349 	Validation Loss: 2.987952
# Validation loss decreased (3.159324 --> 2.987952).  Saving model ...
# Epoch 10, Batch 1 loss: 3.313853
# Epoch 10, Batch 101 loss: 3.354671
# Epoch 10, Batch 201 loss: 3.328155
# Epoch 10, Batch 301 loss: 3.309137
# Epoch: 10 	Training Loss: 3.302522 	Validation Loss: 2.823547
# Validation loss decreased (2.987952 --> 2.823547).  Saving model ...
# Epoch 11, Batch 1 loss: 2.899783
# Epoch 11, Batch 101 loss: 3.194901
# Epoch 11, Batch 201 loss: 3.190028
# Epoch 11, Batch 301 loss: 3.173358
# Epoch: 11 	Training Loss: 3.165751 	Validation Loss: 2.660875
# Validation loss decreased (2.823547 --> 2.660875).  Saving model ...
# Epoch 12, Batch 1 loss: 3.115279
# Epoch 12, Batch 101 loss: 3.092646
# Epoch 12, Batch 201 loss: 3.084735
# Epoch 12, Batch 301 loss: 3.065739
# Epoch: 12 	Training Loss: 3.058976 	Validation Loss: 2.554900
# Validation loss decreased (2.660875 --> 2.554900).  Saving model ...
# Epoch 13, Batch 1 loss: 2.885458
# Epoch 13, Batch 101 loss: 2.960116
# Epoch 13, Batch 201 loss: 2.970120
# Epoch 13, Batch 301 loss: 2.946106
# Epoch: 13 	Training Loss: 2.938856 	Validation Loss: 2.402245
# Validation loss decreased (2.554900 --> 2.402245).  Saving model ...
# Epoch 14, Batch 1 loss: 2.588466
# Epoch 14, Batch 101 loss: 2.867188
# Epoch 14, Batch 201 loss: 2.855871
# Epoch 14, Batch 301 loss: 2.855992
# Epoch: 14 	Training Loss: 2.849871 	Validation Loss: 2.281991
# Validation loss decreased (2.402245 --> 2.281991).  Saving model ...
# Epoch 15, Batch 1 loss: 2.386358
# Epoch 15, Batch 101 loss: 2.776725
# Epoch 15, Batch 201 loss: 2.778352
# Epoch 15, Batch 301 loss: 2.760730
# Epoch: 15 	Training Loss: 2.755415 	Validation Loss: 2.163017
# Validation loss decreased (2.281991 --> 2.163017).  Saving model ...
# Epoch 16, Batch 1 loss: 2.740516
# Epoch 16, Batch 101 loss: 2.675367
# Epoch 16, Batch 201 loss: 2.651939
# Epoch 16, Batch 301 loss: 2.650673
# Epoch: 16 	Training Loss: 2.654271 	Validation Loss: 2.072724
# Validation loss decreased (2.163017 --> 2.072724).  Saving model ...
# Epoch 17, Batch 1 loss: 2.219394
# Epoch 17, Batch 101 loss: 2.569752
# Epoch 17, Batch 201 loss: 2.579750
# Epoch 17, Batch 301 loss: 2.582037
# Epoch: 17 	Training Loss: 2.577489 	Validation Loss: 1.993658
# Validation loss decreased (2.072724 --> 1.993658).  Saving model ...
# Epoch 18, Batch 1 loss: 2.953488
# Epoch 18, Batch 101 loss: 2.519098
# Epoch 18, Batch 201 loss: 2.524193
# Epoch 18, Batch 301 loss: 2.511758
# Epoch: 18 	Training Loss: 2.506337 	Validation Loss: 1.917594
# Validation loss decreased (1.993658 --> 1.917594).  Saving model ...
# Epoch 19, Batch 1 loss: 2.360987
# Epoch 19, Batch 101 loss: 2.413469
# Epoch 19, Batch 201 loss: 2.431634
# Epoch 19, Batch 301 loss: 2.428597
# Epoch: 19 	Training Loss: 2.422167 	Validation Loss: 1.817427
# Validation loss decreased (1.917594 --> 1.817427).  Saving model ...
# Epoch 20, Batch 1 loss: 2.604393
# Epoch 20, Batch 101 loss: 2.399111
# Epoch 20, Batch 201 loss: 2.383199
# Epoch 20, Batch 301 loss: 2.362615
# Epoch: 20 	Training Loss: 2.356920 	Validation Loss: 1.766921
# Validation loss decreased (1.817427 --> 1.766921).  Saving model ...

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images. Use the code cell below to calculate and print the test loss and accuracy.  Ensure that your test accuracy is greater than 60%.

# %%
test(loaders_transfer, model_transfer, criterion_transfer, use_cuda)
# Out:
# Test Loss: 1.839703
#
#
# Test Accuracy: 72% (602/836)

# %% [markdown]
# ### (IMPLEMENTATION) Predict Dog Breed with the Model
#
# Write a function that takes an image path as input and returns the dog breed (`Affenpinscher`, `Afghan hound`, etc) that is predicted by your model.

# %%
### TODO: Write a function that takes a path to an image as input
### and returns the dog breed that is predicted by the model.

# list of class names by index, i.e. a name can be accessed like class_names[0]
class_names = [item[4:].replace("_", " ") for item in loaders_transfer['train'].dataset.classes]

from PIL import Image
import torchvision.transforms as transforms

def load_input_image(img_path):    
    image = Image.open(img_path).convert('RGB')
    prediction_transform = transforms.Compose([transforms.Resize(size=(224, 224)),
                                     transforms.ToTensor(), 
                                     standard_normalization])
    image = prediction_transform(image)[:3,:,:].unsqueeze(0)
    return image
def predict_breed_transfer(img_path,class_names,model):
    # load the image and return the predicted breed
    img = load_input_image(img_path)
    model = model.cpu()
    model.eval()
    idx = torch.argmax(model(img))
    return class_names[idx]

# %% [markdown]
# ---
# <a id='step5'></a>
# ## Step 5: Write your Algorithm
#
# Write an algorithm that accepts a file path to an image and first determines whether the image contains a human, dog, or neither.  Then,
# - if a __dog__ is detected in the image, return the predicted breed.
# - if a __human__ is detected in the image, return the resembling dog breed.
# - if __neither__ is detected in the image, provide output that indicates an error.
#
# You are welcome to write your own functions for detecting humans and dogs in images, but feel free to use the `face_detector` and `human_detector` functions developed above.  You are __required__ to use your CNN from Step 4 to predict dog breed.
#
# Some sample output for our algorithm is provided below, but feel free to design your own user experience!
#
# ![Sample Human Output](images/sample_human_output.png)
#
#
# ### (IMPLEMENTATION) Write your Algorithm

# %%
### TODO: Write your algorithm.
### Feel free to use as many code cells as needed.
import matplotlib.pyplot as plt                        
# %matplotlib inline 
def run_app(img_path):
    ## handle cases for a human face, dog, and neither
    img = Image.open(img_path)
    plt.imshow(img)
    plt.show()
    if dog_detector(img_path) is True:
        prediction = predict_breed_transfer(img_path, class_names,model_transfer)
        print("Dogs Detected!\nIt looks like a {0}".format(prediction))  
    elif face_detector(img_path) > 0:
        prediction = predict_breed_transfer(img_path,class_names,model_transfer)
        print("Hello, human!\nIf you were a dog..You may look like a {0}".format(prediction))
    else:
        print("Error! Can't detect anything..")

# %%
import os

path = os.getcwd()

print(path)
# Out:
# /home/workspace/dog_project

# %% [markdown]
# ---
# <a id='step6'></a>
# ## Step 6: Test Your Algorithm
#
# In this section, you will take your new algorithm for a spin!  What kind of dog does the algorithm think that _you_ look like?  If you have a dog, does it predict your dog's breed accurately?  If you have a cat, does it mistakenly think that your cat is a dog?
#
# ### (IMPLEMENTATION) Test Your Algorithm on Sample Images!
#
# Test your algorithm at least six images on your computer.  Feel free to use any images you like.  Use at least two human and two dog images.
#
# __Question 6:__ Is the output better than you expected :) ?  Or worse :( ?  Provide at least three possible points of improvement for your algorithm.

# %% [markdown]
# __Answer:__ (Three possible points for improvement)
# -More image datasets of dogs will improve training models.
# -Hyper-parameter tunings: weight initializings, learning rates, drop-outs, batch_sizes
# -More training iterations or epochs and visualization of training loss and validation loss curve to enable choosing optimal hyper-parameters

# %%
## TODO: Execute your algorithm from Step 6 on
## at least 6 images on your computer.
## Feel free to use as many code cells as needed.
human_files=['/home/workspace/dog_project/my_images/human1.jpg', '/home/workspace/dog_project/my_images/human2.jpg', '/home/workspace/dog_project/my_images/human3.jpg' ]
dog_files=['/home/workspace/dog_project/my_images/dog1.jpg', '/home/workspace/dog_project/my_images/dog2.jpg', '/home/workspace/dog_project/my_images/dog3.jpg' ]
## suggested code, below
for file in np.hstack((human_files[:3], dog_files[:3])):
    run_app(file)
# Out:
# Hello, human!
# If you were a dog..You may look like a Bull terrier
# Hello, human!
# If you were a dog..You may look like a Boston terrier
# Hello, human!
# If you were a dog..You may look like a Chihuahua
# Dogs Detected!
# It looks like a Labrador retriever
# Dogs Detected!
# It looks like a Pomeranian
# Dogs Detected!
# It looks like a Chesapeake bay retriever
